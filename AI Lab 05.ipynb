# %%
# !conda install -c anaconda networkx
# Out:
# ^C

# %%
import networkx as nx
import matplotlib.pyplot as plt
def uniform_cost_search(goal, start):
    # Find the minimum cost from starting to the given goal state.
    global graph,cost
    answer = []

    # create a priority queue
    queue = []

    # set the answer vector to max value
    for i in range(len(goal)):
        answer.append(10**8)

    # insert the starting index
    queue.append([0, start])

    # map to store visited node
    visited = {}

    # count
    count = 0

    # while the queue is not empty
    while (len(queue) > 0):

        # get the top element of the
        queue = sorted(queue)
        p = queue[-1]

        # pop the element
        del queue[-1]

        # get the original value
        p[0] *= -1

        # check if the element is part of
        # the goal list
        if (p[1] in goal):

            # get the position
            index = goal.index(p[1])

            # if a new goal is reached
            if (answer[index] == 10**8):
                count += 1

            # if the cost is less
            if (answer[index] > p[0]):
                answer[index] = p[0]

            # pop the element
            del queue[-1]

            queue = sorted(queue)
            if (count == len(goal)):
                return answer

        # check for the non visited nodes
        # which are adjacent to present node
        if (p[1] not in visited):
            for i in range(len(graph[p[1]])):
                queue.append( [(p[0] + cost[(p[1], graph[p[1]][i])])* -1, graph[p[1]][i]])

        # mark as visited
        visited[p[1]] = 1

    return answer

# main function

graph,cost = [[] for i in range(8)],{}

graph[0].append(1)
graph[0].append(3)
graph[3].append(1)
graph[3].append(6)
graph[3].append(4)
graph[1].append(6)
graph[4].append(2)
graph[4].append(5)
graph[2].append(1)
graph[5].append(2)
graph[5].append(6)
graph[6].append(4)

    # add the cost
cost[(0, 1)] = 2
cost[(0, 3)] = 5
cost[(1, 6)] = 1
cost[(3, 1)] = 5
cost[(3, 6)] = 6
cost[(3, 4)] = 2
cost[(2, 1)] = 4
cost[(4, 2)] = 4
cost[(4, 5)] = 3
cost[(5, 2)] = 6
cost[(5, 6)] = 3
cost[(6, 4)] = 7

    # goal state
goal = []

# Visualization of the Graph:

G = nx.cubical_graph()
pos = nx.spring_layout(G, seed=3113794652)  # positions for all nodes

G = nx.Graph()
# G.add_node(0)
# G.add_node(1)
# G.add_node(2)
# G.add_node(3)
# G.add_node(4)
# G.add_node(5)
# G.add_node(6)

# nodes
options = {"edgecolors": "tab:gray", "node_size": 800, "alpha": 0.9}
nx.draw_networkx_nodes(G, pos, nodelist=[0, 1, 2, 3], node_color="tab:red", **options)
nx.draw_networkx_nodes(G, pos, nodelist=[4, 5, 6], node_color="tab:blue", **options)



	# A way for adding edges in networkx, this is for practice
# G.add_edge(0,1, weight= 2)
# G.add_edge(0,3, weight= 5)
# G.add_edge(1,6, weight= 1)

# G.add_edge(3,1, weight= 5)
# G.add_edge(3,6, weight= 6)
# G.add_edge(3,4, weight= 2)

# G.add_edge(2,1, weight= 4)
# G.add_edge(4,2, weight= 4)

# G.add_edge(4,5, weight=3)
# G.add_edge(5,2, weight=6)
# G.add_edge(5,6, weight=3)
# G.add_edge(6,4, weight=7)

nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5)
nx.draw_networkx_edges(
    G,
    pos,
    edgelist=[(0, 1),(0,3),(1,6),(2,1),(3,1),(3,4),(3,6)],
    width=8,
    alpha=0.5,
    edge_color="tab:blue",
)
nx.draw_networkx_edges(
    G,
    pos,
    edgelist=[(4, 5), (5,2) ,(5, 6), (6, 4)],
    width=8,
    alpha=0.5,
    edge_color="tab:blue",
)




goal_state = int(input("Enter the goal node plz: "))
goal.append(goal_state)
answer = uniform_cost_search(goal, 0)


nx.draw_networkx_nodes(G, pos, nodelist=[0, goal_state], node_color="tab:red", **options)
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5)
nx.draw_networkx_edges(
    G,
    pos,
    edgelist=[(0, goal_state)],
    width=8,
    alpha=0.5,
    edge_color="tab:green",
)


labels = {}
labels[0] = r"$0$"
labels[1] = r"$1$"
labels[2] = r"$2$"
labels[3] = r"$3$"
labels[4] = r"$4$"
labels[5] = r"$5$"
labels[6] = r"$6$"
nx.draw_networkx_labels(G, pos, labels, font_size=20, font_color="white")

plt.tight_layout()
plt.axis("off")
plt.show()

print("Minimum cost from initial_node{0} to goal_state is = ",answer[0])
# Out:
# Enter the goal node plz: 5
# Minimum cost from initial_node{0} to goal_state is =  10

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

n = int(input("Enter how many nodes you want to enter:"))
for i in range(n):
    n1 = input("Enter the node: ")
    G.add_node(n1)
    
e = int(input("Enter how many edges you want to give:"))
for i in range(0, e):
    a = input().split()
    if a[0].lower() == "no":
        break
#     li = [int(i) for i in a]

    G.add_edge(a[0], a[1])
   
print(nx.info(G))
nx.draw(G, with_labels=True)
plt.show()

# G.add_node("R1")
# G.add_node("R2")
# G.add_node("R3")
# G.add_edge("R1","R2")
# G.add_edge("R1","R3")
# G.add_edge("R2","R3")
# Out:
# Enter how many nodes you want to enter:6
# Enter the node: a
# Enter the node: b
# Enter the node: c
# Enter the node: d
# Enter the node: e
# Enter the node: f
# Enter how many edges you want to give:7
# a b
# a c
# b c
# c e
# d e
# b d
# d f
# Graph with 6 nodes and 7 edges

# %%
# importing the required module
import matplotlib.pyplot as plt

# x axis values
x = [1,2,3]
# corresponding y axis values
y = [2,4,1]

# plotting the points
plt.plot(x, y)

# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')

# giving a title to my graph
plt.title('My first graph!')

# function to show the plot
plt.show()

# %%
import networkx as nx
G = nx.Graph()
G.add_node(1)
G.add_node(2)
G.add_node(3)
G.add_node(4)
# G.add_nodes_from([2, 3])
G.add_nodes_from([
    (4, {"color": "red"}),
    (5, {"color": "green"}),
    (6, {"color": "blue"}),
])

G.add_edge(1, 2)
e = (2, 3)
G.add_edge(*e)  # unpack edge tuple*
G.add_edge(4,5)
G.add_edge(5,6)
print(nx.info(G))
nx.draw(G,with_labels=True)
# Out:
# Graph with 6 nodes and 4 edges

# %%
G = nx.cubical_graph()
pos = nx.spring_layout(G, seed=3113794652)  # positions for all nodes

# nodes
options = {"edgecolors": "tab:gray", "node_size": 800, "alpha": 0.9}
nx.draw_networkx_nodes(G, pos, nodelist=[0, 1, 2, 3], node_color="tab:red", font_color= "white", **options)
nx.draw_networkx_nodes(G, pos, nodelist=[4, 5, 6, 7], node_color="tab:blue", **options)

# edges

nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5)
nx.draw_networkx_edges(
    G,
    pos,
    edgelist=[(0, 1), (1, 2), (2, 3), (3, 0)],
    width=8,
    alpha=0.5,
    edge_color="tab:red",
)
nx.draw_networkx_edges(
    G,
    pos,
    edgelist=[(4, 5), (5, 6), (6, 7), (7, 4)],
    width=8,
    alpha=0.5,
    edge_color="tab:blue",
    
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1872/2671493996.py in <module>
# ----> 1 G = nx.cubical_graph()
#       2 pos = nx.spring_layout(G, seed=3113794652)  # positions for all nodes
#       3
#       4 # nodes
#       5 options = {"edgecolors": "tab:gray", "node_size": 800, "alpha": 0.9}
#
# NameError: name 'nx' is not defined

# %%
G = nx.Graph([(1, 2, {"color": "black"})])
G.add_edge(2,3)
nx.draw(G,with_labels=True)
G.add_edge(1, 2)
H = nx.DiGraph(G)  # create a DiGraph using the connections from G
list(H.edges())
# Out:
# [(1, 2), (2, 1), (2, 3), (3, 2)]

# %%
G.add_edges_from([(1, 2), (1, 3)])
G.add_node(1)
G.add_edge(1, 2)
G.add_node("spam")        # adds node "spam"
G.add_nodes_from("spam")  # adds 4 nodes: 's', 'p', 'a', 'm'
G.add_edge(3, 'm')
nx.draw(G, with_labels=True)

# %%
# Another way of inserting nodes:
H = nx.path_graph(10)
G.add_nodes_from(H)
nx.draw(G, with_labels=True)

# %%
def closed_search(closed_list:set,graph,start,end):
    
    current = start #c
    if current == end:
        print(end)
        return True
    if current not in closed_list:#true
        print(f"{current} --> ",end="")#c
    
    closed_list.add(current)#c


    x_ = random.choice(graph[current])#b
    if not x_:   
        print("")
        return False
    elif x_ and x_ not in closed_list:
        current = x_
closed_search(closed_list,graph,current,end)
